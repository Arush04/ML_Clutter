# %%
from utils import Trainer, FashionMNIST
from modern_model import VGG, init_cnn

# %%
model = VGG(arch=((1, 16), (1, 32), (2, 64), (2, 128), (2, 128)), lr=0.01)
trainer = Trainer(max_epochs=10, num_gpus=1)
data = FashionMNIST(batch_size=64, resize=(224, 224))
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 data = FashionMNIST(batch_size=64, resize=(224, 224))
#       4 model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
# ----> 5 trainer.fit(model, data)
#
# File ~/Arush/ML_Clutter/experiments/utils.py:170, in Trainer.fit(self, model, data)
#     168 self.total_train_batches = 0
#     169 for self.epoch in range(self.max_epochs):
# --> 170     self.fit_epoch()
#     171 train_loss = self.total_train_loss / self.total_train_batches
#     172 print(f"Final Train Loss: {train_loss:.4f}")
#
# File ~/Arush/ML_Clutter/experiments/utils.py:183, in Trainer.fit_epoch(self)
#     181 for batch in self.train_dataloader:
#     182     batch = self.to_device(batch)
# --> 183     loss = self.model.training_step(batch)
#     184     self.total_train_loss += loss.item()
# ...

# %%
# Source - https://stackoverflow.com/a/74012970
# Posted by Alex, modified by community. See post 'Timeline' for change history
# Retrieved 2025-12-16, License - CC BY-SA 4.0
import torch
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 281

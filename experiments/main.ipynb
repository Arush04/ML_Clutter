# %%
from model import WeightDecayPenalty
from utils import ProgressBoard, Data, Trainer

# %%
data = Data(num_train=20, num_val=20, num_inputs=200, batch_size=4)
trainer = Trainer(max_epochs=20)

def train(lbd):
    model = WeightDecayPenalty(num_inputs=200, lbd=lbd, lr=0.01)
    trainer.fit(model, data)

# %%
train(0), train(1)
# Out:
# (None, None)
